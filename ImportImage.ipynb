# %% [markdown]
# <a href="https://colab.research.google.com/github/sovan2001/Data-Science-Learning/blob/main/ImportImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Embed = Image('https://i.redd.it/oq9rjrbhge051.png')
Embed
